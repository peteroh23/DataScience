# %% [markdown]
# <p style="font-family: Times New Roman; font-size:3.75em;color:black; font-style:bold"><br>
# Project A, Peter Oh </p><br>

# %% [markdown]
# # Summary of Data

# %% [markdown]
# Basic Information:
#
# - 81 Columns (Categories, i.e. OverallQual, YrSold, etc)
# - 1461 Rows (Houses)
# - Target Variable: SalePrice

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

train_data = './train.csv'

df = pd.read_csv(train_data)

# %% [markdown]
# Importing Necessary modules & Reading csv file

# %% [markdown]
# Printing out first row information

# %%
row_0 = df.iloc[0]
print(row_0)
# Out:
# Id                     1
# MSSubClass            60
# MSZoning              RL
# LotFrontage           65
# LotArea             8450
# Street              Pave
# Alley                NaN
# LotShape             Reg
# LandContour          Lvl
# Utilities         AllPub
# LotConfig         Inside
# LandSlope            Gtl
# Neighborhood     CollgCr
# Condition1          Norm
# Condition2          Norm
# BldgType            1Fam
# HouseStyle        2Story
# OverallQual            7
# OverallCond            5
# YearBuilt           2003
# YearRemodAdd        2003
# RoofStyle          Gable
# RoofMatl         CompShg
# Exterior1st      VinylSd
# Exterior2nd      VinylSd
# MasVnrType       BrkFace
# MasVnrArea           196
# ExterQual             Gd
# ExterCond             TA
# Foundation         PConc
#                   ...
# BedroomAbvGr           3
# KitchenAbvGr           1
# KitchenQual           Gd
# TotRmsAbvGrd           8
# Functional           Typ
# Fireplaces             0
# ...

# %% [markdown]
# Basic Summary of Data

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# Mean of Each Column of Data, Relative understanding of the number range (for Categories that have numbers)

# %%
df.mean()
# Out:
# Id                  730.500000
# MSSubClass           56.897260
# LotFrontage          70.049958
# LotArea           10516.828082
# OverallQual           6.099315
# OverallCond           5.575342
# YearBuilt          1971.267808
# YearRemodAdd       1984.865753
# MasVnrArea          103.685262
# BsmtFinSF1          443.639726
# BsmtFinSF2           46.549315
# BsmtUnfSF           567.240411
# TotalBsmtSF        1057.429452
# 1stFlrSF           1162.626712
# 2ndFlrSF            346.992466
# LowQualFinSF          5.844521
# GrLivArea          1515.463699
# BsmtFullBath          0.425342
# BsmtHalfBath          0.057534
# FullBath              1.565068
# HalfBath              0.382877
# BedroomAbvGr          2.866438
# KitchenAbvGr          1.046575
# TotRmsAbvGrd          6.517808
# Fireplaces            0.613014
# GarageYrBlt        1978.506164
# GarageCars            1.767123
# GarageArea          472.980137
# WoodDeckSF           94.244521
# OpenPorchSF          46.660274
# ...

# %% [markdown]
# Correlation of the Categories (that contain numbers)

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %% [markdown]
# Every Column Name, 81 Different Categories

# %%
row_0.index
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# # Manipulating Data

# %% [markdown]
# Checking if any Columns contain Null Values

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %% [markdown]
# # Meaning of Null Columns:

# %% [markdown]
# LotFrontage: Linear feet of street connected to property
#
# Alley: Type of alley access to property
#
# MasVnrType: Masonry veneer type
#
# MasVnrArea: Masonry veneer area in square feet
#
# BsmtQual: Evaluates the height of the basement
#
# BsmtCond: Evaluates the general condition of the basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
# BsmtFinType1: Rating of basement finished area
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
# Electrical: Electrical system
#
# FireplaceQu: Fireplace quality
#
# GarageType: Garage Location
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finsih of the garage
#
# GarageQual: Garage Quality
#
# GarageCond: Garage condition
#
# PoolQC: Pool quality
#
# Fence: Fence quality
#
# MiscFeature: Miscellaneous feature not covered in other categories

# %% [markdown]
# Replacing NaN with 0.0 for LotFrontage

# %%
df.LotFrontage.fillna(value= 0.0, inplace=True)

# %% [markdown]
# Replacing NaN with 0.0 for MasVnrArea

# %%
df.MasVnrArea.fillna(value= 0.0, inplace=True)

# %% [markdown]
# Replacing NaN with "None" for rest of Categories

# %%
df.fillna(value =  "None", inplace = True)
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
# 5   6          50       RL         85.0    14115   Pave  None      IR1
# 6   7          20       RL         75.0    10084   Pave  None      Reg
# 7   8          60       RL          0.0    10382   Pave  None      IR1
# 8   9          50       RM         51.0     6120   Pave  None      Reg
# 9  10         190       RL         50.0     7420   Pave  None      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0   None   None        None       0
# ...

# %% [markdown]
# # Understanding Data (Plots, Graphs, etc)

# %% [markdown]
# Relationship Between SalePrice and OverallQual

# %%
df_1 = pd.DataFrame(df, columns= ['OverallQual', 'SalePrice'])
df_1.head(10)
# Out:
#    OverallQual  SalePrice
# 0            7     208500
# 1            6     181500
# 2            7     223500
# 3            7     140000
# 4            8     250000
# 5            5     143000
# 6            8     307000
# 7            7     200000
# 8            7     129900
# 9            5     118000

# %%
fig = plt.figure()
plt.scatter(df['OverallQual'], df['SalePrice'])
plt.title('Overall Quality of House vs. Sale Price of House')
plt.xlabel('Overall Quality')
plt.ylabel('Sale Price')
plt.show(fig)

# %% [markdown]
# Relationship Between SalePrice and GrLivArea

# %%
df_1 = pd.DataFrame(df, columns= ['GrLivArea', 'SalePrice'])
df_1.head(10)sklearn.metrics.mean_squared_error(y_true = valid_target, y_pred=predictions)
# Out:
#    GrLivArea  SalePrice
# 0       1710     208500
# 1       1262     181500
# 2       1786     223500
# 3       1717     140000
# 4       2198     250000
# 5       1362     143000
# 6       1694     307000
# 7       2090     200000
# 8       1774     129900
# 9       1077     118000

# %%
fig1 = plt.figure()
plt.scatter(df['GrLivArea'], df['SalePrice'])
plt.title('Overall Area of House vs. Sale Price of House')
plt.xlabel('Area of House')
plt.ylabel('Sale Price')
plt.show(fig1)

# %% [markdown]
# Linear Regression of Area of House vs. Sale Price of House

# %%
import sklearn.datasets
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

X = df['GrLivArea'].values[:,np.newaxis]

y = df['SalePrice'].values

model = LinearRegression()

model.fit(X,y)

plt.scatter(X, y, color='r')

plt.plot(X, model.predict(X), color = 'k')

plt.show()

# %%
sklearn.metrics.mean_squared_error(X, model.predict(X))
# Out:
# 35294514849.073875
